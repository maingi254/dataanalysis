# %% [markdown]
# # DATA VALIDATION
# The dataset contained 8 columns and 2000 rows.
# These were columns with wrong data types:
#     i)Claim_amount data type was a text.
#     ii)Amount_paid datatype was  text.
#
#
#  Lets review the column data
# 1.  claim_id -The data matched the description given and there was no missing values
# 2.  time_to_close - The data matched the description given and there was no missing values to it.
# 3.  claim_amount - The data was in text datatype.I first split the text to remove the currency symbol form it  from the number and converted the datatype to currency for easy calculation.I renamed the column claim_amount_in_R$ and rounded off the data into 2 decimal place digits.There was no missing values in this column.The column had 2000 distinct values.
# 5.  Amount_paid - The datatype was text which needed to be converted into 2 decimal place digits and renamed the column to 'amount_paid_in_R$'.The column had 36 missing values which i replaced with the median amount of te column data.
# 6.  location- The datatype was according to the description and its had 4 distinct values.its datatype is text.
# 7.  individuals_on_claim - The datatype was according to the description.The datatype was whole numbers.There was no missing values in this column.The column had 15 distinct data values.
# 8.  linked_cases.The data was converted from text to 'false/true' datatype.There were 26 missing values from the column data which were replaced with 'FALSE' value.The data has only two distinct values.
# 9.  cause.The data has data inconsistencies where there were two values 'Meat' and 'meat'.combined the two into one and cleaned the inconsistencies.There were no missing values in this column.The datatype was in text format.

# %% [markdown]
# ## Task 2

# %% [markdown]
# ![number of claims in each location](NUMBER_OF_CLAIMS_ON_EACH_LOCATION.png)

# %% [markdown]
# ## In figure **number of claims in each location**
#
# 1.Recife has  most cases at 7101 total cases, 2940 more cases than Sao luis location.
# 2.Natal has the least cases 2329 cases ,179 cases less than Fortaleza location.

# %% [markdown]
# ![Cause of claims on each location](cause_of_claims_per_location.png)

# %% [markdown]
# ## The figure highlights the cause of claims on each location
#
# 1. Recife has most claims among the locations most of which are caused by meat.
# 2. Sao luis has second most claims most of which are caused by meat.
# 3. Meat is the leading cause of claims on all four locations.
# 4. Vegetables have the least amount of claims made on the different locations.

# %% [markdown]
# ![total count based on location](TOTAL_COUNT_ON_LOCATION.png)

# %% [markdown]
# In figure **Total count on location**
# 1. Recife has the most count of cases with 451 cases.
# 2. Sao luis has 243 cases.
# 3. Natal has 155 cases.
# 4. Fortaleza has 151 cases.

# %% [markdown]
# ![Distribution of individuals in a claim](DISTRIBUTION_OF_INDIVIDUALS_IN_A_CLAIMS.png)

# %% [markdown]
# ## Distribution of individuals in a claim
#
# 1. Most claims have between 5 to 12 individuals in a claim.

# %% [markdown]
# ![amount paid for each cause per location](amount_paid_for_each_cause_per_location.png)

# %% [markdown]
# ![claim amount paid on each cause per location](claim_paid_on_cause_based_on_location.png)

# %% [markdown]
# _Write your answer here_

# %% [markdown]
# ## In figure Total number of amount paid and total claim amount paid
# 1. Recife has the highest amount claimed and amount paid.most of the amount is paid to unknown causes while vegetable has the least amount paid.
# 2. Sao luis has second most amount paid  with most amount paid and  amount claimed to unknown cause followed by meat and vegetable as the least amount paid.
# 3. Fortaleza follows with the most ammount paid and amount claimed to meat cause while vegetables has the least amount paid.
# 4. Natal has the least amount paid among the 4 locations while most of the amount paid and amount claimed goes to unknown causes and vegetables being the least cause for the amount paid and claimed.
# 5. Vegetables has the least amount paid  and amount claimed for the causes across all the locations.
# 6. Unknown causes has the most amount paid and amount claimed for in the 4 locations.

# %% [markdown]
# ## Task 3

# %% [markdown]
# ![distribution of time to close all claims](DISTRIBUTION_OF_TIME_IT_TAKES_TO_CLOSE_A_CLAIM.png)

# %% [markdown]
# ![The distribution of time to close all claims](TIME_TAKEN_TO_CLOSE_A_CASE.png)

# %% [markdown]
# ## The distribution of time taken to close all claims
# ##
#
# 1. Most of the claims are closed between 100 to 200 days.
# 2. The most time taken to close a claim is 518 days.
# 3. The least time taken to close a claim is 93 days.

# %% [markdown]
# ## Task 4

# %% [markdown]
# ![Time Taken to close a claim on location](TIME_TAKEN_TO_CLOSE_A_CASE_BASED_ON_LOCATION.png)

# %% [markdown]
# ## Relationship between time to close and location
#
#
# 1. Fortaleza region takes the minimum amount of days to close a claim at 76 days while Recipe takes 6 days more.
# 2. Natal a minumum of 93 days to close a claim while Sao lius takes 84 days to close the claims.
# 3. Sao lius takes a maximu of 518 days to close a claim.Fortaleza takes a maximum of 453 days to close a claim while Recipe and Natal take 427 and 361 days to close a claim respectively.
# 4. The legal team can assist Sao luis region to reduce the amount of days for closing the claim.
# 5. The legal team can reduce the days it takes by adding more personel.
# 6. The legal department should set a benchmark for the maximum time for a case to be closed.

# %% [markdown]
# ## RECOMMENDATION
#
# - The legal team can assign more staff to the location with the most cases which is Recife.
# - The leading cause of cases are unknown cases in most location while vegetables cases are the least in all location.The management can inspect the meat before its stocked to the store.
# -Vivendo management can put measures that ensure that the meat consumed is properly vetted.
# - The food chains opened in recife should be put under strict cleanness control so as to reduce the cases in the location.
# -
